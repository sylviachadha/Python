# %%
# Arrays in python

# %%
l = [234,87654,934,234,-946]

# %%
print
# Out:
# <function print>

# %%
print(l)
# Out:
# [234, 87654, 934, 234, -946]

# %%
# Lists are similar to arrays in other programming languages like C, C++ and
# similar to vectors in R however in Python list has a property that they can store 
# mixed data type like integers, numbers, logical values etc

# %%
# In python another data structure is Arrays. There are 2 types of arrays in Python
# Array arrays are built into the core of Python. Another are numpy arrays. Numpy arrays
# are much more versatile and they have much more flexibility to them.

# %%
import numpy as np

# %%
a = np.array(l)

# %%
print(a)
# Out:
# [  234 87654   934   234  -946]

# %%
# An array cannot be of different data types so array is like a vector in R
# We pass a list to np.array

# %%
b = np.array([2,435,63.3,True,"abc"])

# %%
print(b)
# Out:
# ['2' '435' '63.3' 'True' 'abc']

# %%
# We observe that all were converted to strings since array can take only 1 data type.

# %%
# An array is less flexible than a list as in list we can have mixxed data types but in
# array we cannot then why use array ?
# Check 1. and 2. for ans

# %%
#In this object list there are functions / methods that are stored
# eg l.pop

# %%
l.pop()
# Out:
# -946

# %%
print(l)
# Out:
# [234, 87654, 934, 234]

# %%
#1.In this object array there are way more methods available
#Many powerful functions available for arrays that come with numpy
a.mean()
# Out:
# 17622.0

# %%
#2.We will be creating multi dimensional objects specifically matrices which are 
#two dimensional array.Also for data analytics purpose good to start with array
