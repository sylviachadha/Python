# %%
# Python_Fundamentals_Recap

# %%
# List
# Create lists using [] and range function
# Use square brackets to access list
# Slicing list, use : operator to slice lists
# Tuples are like lists but immutable u cannot change values of tuples
# Functions in Python, compared to blender u give some inputs and u
# get some outputs
# Packages in Python
# Numpy is a package that is quite often used being a data scientist 
# using python
# Arrays - types of arrays 1D, 2D .. Matrices
# Slicing arrays
