# %%
# Section Recap Core Programming Principles

# Types of variables
# Integers, Float, String, Boolean / Logical
# Integers and float help us to perform arithmetic operations
# String helps to store textual data
# Boolean allow us to work with with loops and conditional statements,
# basically evaluate logical expressions

# Concatenate strings

# and , or , not spelt as words rather than symbols in Python

# While loop

# Python is not a vectorized programming language so heavy load on loops

# For loop , range function to create ranges for for loop

# if elif and else statements. Nest and chain them.

# Generate random number randn() function from the numpy package
