# %%
# Using Variables
# Working with variables

A = 10
B = 5
C = A + B

# %%
C
# Out:
# 15

# %%
D = B / A

# %%
D
# Out:
# 0.5

# %%
print(D)
# Out:
# 0.5

# %%
C
D
# Out:
# 0.5

# %%
print(C)
print(D)
# Out:
# 15
# 0.5

# %%
# Always use print() function to display any value

import math
# Inorder to use sqrt need to import math

# %%
math.sqrt(144)
# Out:
# 12.0

# %%
math.sqrt(A)
# Out:
# 3.1622776601683795

# %%
round(math.sqrt(A))
# Out:
# 3

# %%
# working with string
greeting = "Hello"
name = "Bob"
message = greeting + " " + name

# %%
message
# Out:
# 'Hello Bob'

# %%
print(message)
# Out:
# Hello Bob
