# %%
# Types of Variables
# Integer
# No need to initialize or declare type of variable as high level
x = 2

# %%
x
# Out:
# 2

# %%
type(x)
# Out:
# int

# %%
# All integers represent whole numbers 
# Integers 2.0
# Integers take up less space in terms of memory and storage

# %% [markdown]
# ---

# %%
# Float / double
# float is a number with decimal point
y = 2.5
y
# Out:
# 2.5

# %%
type(y)
# Out:
# float

# %%
# Escape - mode to only view
# Enter - mode to edit
# m for markdown when not in edit mode

# %% [markdown]
# ---

# %%
# String
# In python does not matter double or single quotation
# used to store words, letters or even numbers like eg shown below
a = "hello"
a

b = 'hello2'
b
# Out:
# 'hello2'

# %%
type(a)
# Out:
# str

# %%
a = "hello"
a
# Out:
# 'hello'

# %%
c = '2'

# %%
c
# Out:
# '2'

# %% [markdown]
# ---

# %%
# Logical / Boolean  data type which is True or False
q1 = True
q1
# Out:
# True

# %%
type(q1)
# Out:
# bool

# %%
#Main 4 types of variables in  Python are Integer, Float, String and Logical / Boolean
