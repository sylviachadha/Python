# %%
# Boolean / Logical Variables and Operators
# True
# False

# %%
4 < 5
# Out:
# True

# %%
10 > 100
# Out:
# False

# %%
4 == 5
# In python need to put == sign to check equality
# Out:
# False

# %% [markdown]
# ---

# %%
# To check if LHS is not equal to RHS
# != or <>. , can use any of these to check inequality
# <
# >
# <=
# >=
# and
# or
# not

# %% [markdown]
# ---

# %%
result = 4 < 5

# %%
result
# Out:
# True

# %%
type(result)
# Out:
# bool

# %%
result1 = 8 < 5

# %%
result1
# Out:
# False

# %%
result2 = not(5 > 1)

# %%
print(result2)
# Out:
# False

# %% [markdown]
# ---

# %%
# Using and / or statement
result or result2
# Out:
# True

# %%
result and result2
# Out:
# False

# %%
print(result)
# Out:
# True

# %%
print(result2)
# Out:
# False

# %%
print(result1)
# Out:
# False
