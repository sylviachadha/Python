# %%
# Installing Programming language Python
# Can code Python through Anaconda Distribution. 
# Anaconda is a pre-packaged solution that already includes Python, Jupyter, some IDE’s, packages like NumPy and Pandas.

# Jupyter previously used to be called as IP[y]thon notebooks but now they have expanded, you can code in Julia, Python and R as well in Jupyter notebook

# Jupyter = Julia + Python + R. It is a solution that works in your browser, instead of installing an IDE and installing Python there you can use Jupyter which will run in your browser.

# Steps to install

#1)	Install Anaconda
#2)	Open Terminal
#3)	Run Jupyter notebook
