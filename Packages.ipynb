# %%
# Packages in Python

# What's inside the Package ? Blenders, that means Functions, maybe other 
# things like classes, data etc
# These functions we want to add to our program / code
# Core of Python comes with a very limited set of functions. U need to 
# include packages to get the functions
# Packages vary in their purpose for eg 1 for visualizations another for
# procesing twitter data

# %%
# A module is simply a file containing Python definition, functions and 
# and statements. Puttting code into module is useful because of the ability 
# to import module functionality into ur script or ipython session

# %%
# A package is just a way of collecting related modules together within
# a single tree like hierarchy. Very complex packages like NumPy and SciPy
# have hundreds of indiviual modules so putting them into directory like
# structure keeps things organised and avoids name collisions.

# %%
# Step 1 - Find package search on Github

# Step 2 - Install the Package.
# open terminal and type below commands
# conda install package_name
# OR
# pip install package_name

# Step 3 - Import Package or Import certain Function

# example
# import scrapy    # this is complete package
# from scrapy.crawler import CrawlerProcess

# %%
import scrapy

# %%
from scrapy.crawler import CrawlerProcess
# Here Scrapy is a package which is a collection of modules and crawler is 
# one module in scrapy which we access via scrapy.crawler and then we
# import function / class from this which is CrawlerProcess. Here 
# CrawlerProcess is a Class. Inside this class CrawlerProcess there are
# many methods.

# %%
import numpy as nm

# %%
# Numpy package is included in Anaconda distribution. It already aggregates
# most popular packages
